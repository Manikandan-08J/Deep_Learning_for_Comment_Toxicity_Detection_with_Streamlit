# %%
print("hello world")
# Out:
# hello world

# %%
print("hello mani")
# Out:
# hello mani

# %%
print("Hi Mani")
# Out:
# Hi Mani

# %%
print('Turn off the lighta')
# Out:
# Turn off the lighta

# %%
print("Instagram")
# Out:
# Instagram

# %%
name = ("Mani")
age = 27
print(name, age)
# Out:
# Mani 27

# %%
print("My name is {} and I am {} years old".format(name, age))
# Out:
# My name is Mani and I am 27 years old

# %%
name = ("Mani")
age = 27
edu = ("B.Com")
print("my name is {} and my age is {} im studied {}".format(name, age, edu))
# Out:
# my name is Mani and my age is 27 im studied B.Com

# %% [markdown]
# ###Multiple_line_statement

# %%
print("My name is mani. \n " \
      "My education is in BCom.\n" \
      "My age is 27")
# Out:
# My name is mani.
#  My education is in BCom.
# My age is 27

# %%
print("Its sunday today. \n" \
      "Im going to take a rest. \n \
tomorrow is monday again")
# Out:
# Its sunday today.
# Im going to take a rest.
#  tomorrow is monday again

# %%
print("my name is mani. \n" \
"my education is in bcom. \n" \
"my age is 27. \n" \
"im working in DHL")
# Out:
# my name is mani.
# my education is in bcom.
# my age is 27.
# im working in DHL

# %% [markdown]
# #####Simple_way_for_multiple_line_statement

# %%
print("""my name is mani
my education is in bcom
my age is 27""")
# Out:
# my name is mani
# my education is in bcom
# my age is 27

# %%
print("""my name is mani
my education is in bcom
my age is 27
im working in dhl""")
# Out:
# my name is mani
# my education is in bcom
# my age is 27
# im working in dhl

# %%
a = b = c = 100
print(a)
print(b)
print(c)
# Out:
# 100
# 100
# 100

# %%
a, b, c = 100, 200, 300
print(a)
print(b)
print(c)
# Out:
# 100
# 200
# 300

# %%
mani = str(1)
print(mani)
# Out:
# 1

# %%
print(type(mani))
# Out:
# <class 'str'>

# %%
text = ("mani")
print(text[0])
# Out:
# m

# %%
print(text[1])
# Out:
# a

# %%
text = ("volks wagon")
print(text[:6])
# Out:
# volks

# %%
print(text[3:])
# Out:
# ks wagon

# %%
print(text[3:7])
# Out:
# ks w

# %%
print(text[6:])
# Out:
# wagon

# %%
print(text[:])
print(text[::])
print(text[::2])
print(text[::3])
# Out:
# volks wagon
# volks wagon
# vlswgn
# vkwo

# %%
text = "volks wagon"
print(len(text))
# Out:
# 11

# %%
name = "manikandan"
print(len(name))
# Out:
# 10

# %%
name = "mani"
print(name*3)
print(type(name))
# Out:
# manimanimani
# <class 'str'>

# %%
a = []
print(a)
print(type(a))
# Out:
# []
# <class 'list'>

# %%
b = [1, 2, 3]
print(b)
print(type(b))
# Out:
# [1, 2, 3]
# <class 'list'>

# %%
c = list((1, 2, 3))
print(c)
print(type(c))
# Out:
# [1, 2, 3]
# <class 'list'>

# %%
d = [1, "apple", [2, 3], (5, 6)]
print(d)
print(type(d))
# Out:
# [1, 'apple', [2, 3], (5, 6)]
# <class 'list'>

# %%
nums = [10, 20, 30, 40, 50, 60, 70]
print(nums[1:4])
print(nums[:3])
print(nums[2:])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50, 60, 70]

# %%
print(nums[::-1])
print(nums[::-3])
# Out:
# [70, 60, 50, 40, 30, 20, 10]
# [70, 40, 10]

# %%
print(nums[::2])
print(nums[::3])
# Out:
# [10, 30, 50, 70]
# [10, 40, 70]

# %%
listt = [1, 2, 3, 4, 5, 6, 7, 8, 9]
print(listt[::2])
print(listt[1::2])
# Out:
# [1, 3, 5, 7, 9]
# [2, 4, 6, 8]

# %%
fruits = ["apple", "banana", "cherry"]
fruits[1] = "blueberry"
print(fruits)
# Out:
# ['apple', 'blueberry', 'cherry']

# %%
fruits[2] = "mango"
print(fruits)
# Out:
# ['apple', 'blueberry', 'mango']

# %%
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'blueberry', 'mango', 'orange']

# %%
fruits.append("pineapple")
print(fruits)
# Out:
# ['apple', 'blueberry', 'mango', 'orange', 'pineapple']

# %%
fruits = ['apple', 'blueberry', 'mango', 'orange', 'pineapple']
fruits.insert(1, "watermelon")
print(fruits)
# Out:
# ['apple', 'watermelon', 'blueberry', 'mango', 'orange', 'pineapple']

# %%
fruits.insert(3, "cucumber")
print(fruits)
# Out:
# ['apple', 'watermelon', 'blueberry', 'cucumber', 'mango', 'orange', 'pineapple']

# %%
listoffruits = ["kiwi, grape"]
fruits.extend(listoffruits)
print(fruits)
# Out:
# ['apple', 'watermelon', 'blueberry', 'cucumber', 'mango', 'orange', 'pineapple', 'kiwi, grape']

# %%
listoffruits1 = ["banana", "red banana"]
fruits.extend(listoffruits1)
print(fruits)
# Out:
# ['apple', 'watermelon', 'blueberry', 'cucumber', 'mango', 'orange', 'pineapple', 'kiwi, grape', 'banana', 'red banana']

# %%
fruits.remove("watermelon")
print(fruits)
# Out:
# ['apple', 'blueberry', 'cucumber', 'mango', 'orange', 'pineapple', 'kiwi, grape', 'banana', 'red banana']

# %%
fruits.remove("orange")
print(fruits)
# Out:
# ['apple', 'blueberry', 'cucumber', 'mango', 'pineapple', 'kiwi, grape', 'banana', 'red banana']

# %%
fruits.pop()
print(fruits)
# Out:
# ['apple', 'blueberry', 'cucumber', 'mango', 'pineapple', 'kiwi, grape', 'banana']

# %%
fruits.pop()
print(fruits)
# Out:
# ['apple', 'blueberry', 'cucumber', 'mango', 'pineapple', 'kiwi, grape']

# %%
listtcars = ['toyota', 'hyundai', 'maruti', 'skoda', 'bmw']
listtcars.remove('bmw')
print(listtcars)
# Out:
# ['toyota', 'hyundai', 'maruti', 'skoda']

# %%
listtcars.append('tata')
print(listtcars)
# Out:
# ['toyota', 'hyundai', 'maruti', 'skoda', 'tata']

# %%
listtcars = ['toyota', 'hyundai', 'maruti', 'skoda', 'tata']
listtcars.insert(2, 'audi')
print(listtcars)
# Out:
# ['toyota', 'hyundai', 'audi', 'maruti', 'skoda', 'tata']
